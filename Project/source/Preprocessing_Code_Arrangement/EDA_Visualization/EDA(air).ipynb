# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline 
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 

if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
    path="c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')
    
plt.style.use('ggplot')
    
plt.rcParams['axes.unicode_minus'] = False

# %%
import os

# %%
os.chdir('C:/Users/JAEMIN/Desktop/air/rerefined_data')

# %%
co = pd.read_csv('refined_co.csv', encoding = 'CP949')
dust = pd.read_csv('refined_dust.csv', encoding = 'CP949')
no2 = pd.read_csv('refined_no2.csv', encoding = 'CP949')
o3 = pd.read_csv('refined_o3.csv', encoding = 'CP949')
so2 = pd.read_csv('refined_so2.csv', encoding = 'CP949')
output = pd.read_csv('onion_unit_ouput.csv')

# %%
output
# Out:
#      year_local   area  year  10a당 생산량 (kg)
# 0    2010_부산광역시  부산광역시  2010           7163
# 1    2011_부산광역시  부산광역시  2011           7393
# 2    2012_부산광역시  부산광역시  2012           6303
# 3    2013_부산광역시  부산광역시  2013           8265
# 4    2014_부산광역시  부산광역시  2014           7271
# ..          ...    ...   ...            ...
# 145    2015_제주도    제주도  2015           6552
# 146    2016_제주도    제주도  2016           6458
# 147    2017_제주도    제주도  2017           6945
# 148    2018_제주도    제주도  2018           6740
# 149    2019_제주도    제주도  2019           7875
#
# [150 rows x 4 columns]

# %%
co = pd.merge(co, output, how = 'outer')
dust = pd.merge(dust, output, how = 'outer')
no2 = pd.merge(no2, output, how = 'outer')
o3 = pd.merge(o3, output, how = 'outer')
so2 = pd.merge(so2, output, how = 'outer')

# %%
dust.shape
# Out:
# (150, 16)

# %%
import seaborn as sns

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='1월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax1)
sns.regplot(x='2월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax2)
sns.regplot(x='3월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax3)
sns.regplot(x='4월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax4)
sns.regplot(x='5월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax5)
sns.regplot(x='6월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax6)

fig, ((ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='7월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax7)
sns.regplot(x='8월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax8)
sns.regplot(x='9월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax9)
sns.regplot(x='10월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax10)
sns.regplot(x='11월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax11)
sns.regplot(x='12월 일산화탄소', y = '10a당 생산량 (kg)', data = co, ax = ax12)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='1월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax1)
sns.regplot(x='2월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax2)
sns.regplot(x='3월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax3)
sns.regplot(x='4월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax4)
sns.regplot(x='5월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax5)
sns.regplot(x='6월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax6)

fig, ((ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='7월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax7)
sns.regplot(x='8월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax8)
sns.regplot(x='9월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax9)
sns.regplot(x='10월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax10)
sns.regplot(x='11월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax11)
sns.regplot(x='12월 미세먼지PM10', y = '10a당 생산량 (kg)', data = dust, ax = ax12)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='1월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax1)
sns.regplot(x='2월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax2)
sns.regplot(x='3월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax3)
sns.regplot(x='4월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax4)
sns.regplot(x='5월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax5)
sns.regplot(x='6월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax6)
fig, ((ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='7월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax7)
sns.regplot(x='8월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax8)
sns.regplot(x='9월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax9)
sns.regplot(x='10월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax10)
sns.regplot(x='11월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax11)
sns.regplot(x='12월 이산화질소', y = '10a당 생산량 (kg)', data = no2, ax = ax12)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='1월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax1)
sns.regplot(x='2월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax2)
sns.regplot(x='3월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax3)
sns.regplot(x='4월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax4)
sns.regplot(x='5월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax5)
sns.regplot(x='6월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax6)
fig, ((ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='7월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax7)
sns.regplot(x='8월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax8)
sns.regplot(x='9월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax9)
sns.regplot(x='10월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax10)
sns.regplot(x='11월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax11)
sns.regplot(x='12월 오존', y = '10a당 생산량 (kg)', data = o3, ax = ax12)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='1월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax1)
sns.regplot(x='2월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax2)
sns.regplot(x='3월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax3)
sns.regplot(x='4월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax4)
sns.regplot(x='5월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax5)
sns.regplot(x='6월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax6)
fig, ((ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(figsize = (15, 10), nrows=2, ncols=3)
sns.regplot(x='7월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax7)
sns.regplot(x='8월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax8)
sns.regplot(x='9월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax9)
sns.regplot(x='10월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax10)
sns.regplot(x='11월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax11)
sns.regplot(x='12월 아황산가스', y = '10a당 생산량 (kg)', data = so2, ax = ax12)

# %%
co = pd.read_csv('refined_co.csv', encoding = 'CP949')
dust = pd.read_csv('refined_dust.csv', encoding = 'CP949')
no2 = pd.read_csv('refined_no2.csv', encoding = 'CP949')
o3 = pd.read_csv('refined_o3.csv', encoding = 'CP949')
so2 = pd.read_csv('refined_so2.csv', encoding = 'CP949')
output = pd.read_csv('onion_unit_ouput.csv')

df = co
air_list = [co, dust, no2, o3, so2, output]

for i in range(1, 6):
    df = pd.merge(df, air_list[i], how = 'outer')
df
# Out:
#      year_local   area  year  7월 일산화탄소  8월 일산화탄소  9월 일산화탄소  10월 일산화탄소  \
# 0    2010_부산광역시  부산광역시  2010       NaN       NaN       NaN        NaN
# 1    2011_부산광역시  부산광역시  2011       0.3       0.3       0.3        0.4
# 2    2012_부산광역시  부산광역시  2012       0.3       0.3       0.3        0.4
# 3    2013_부산광역시  부산광역시  2013       0.4       0.3       0.4        0.4
# 4    2014_부산광역시  부산광역시  2014       0.3       0.4       0.4        0.4
# ..          ...    ...   ...       ...       ...       ...        ...
# 145    2015_제주도    제주도  2015       0.3       0.4       0.3        0.2
# 146    2016_제주도    제주도  2016       0.3       0.4       0.3        0.3
# 147    2017_제주도    제주도  2017       0.4       0.3       0.3        0.3
# 148    2018_제주도    제주도  2018       0.3       0.4       0.3        0.2
# 149    2019_제주도    제주도  2019       0.2       0.2       0.2        0.2
#
#      11월 일산화탄소  12월 일산화탄소  1월 일산화탄소  ...  10월 아황산가스  11월 아황산가스  12월 아황산가스  \
# ...

# %%
df.set_index('year', inplace = True)

# %%
df.corr()
# Out:
#                7월 일산화탄소  8월 일산화탄소  9월 일산화탄소  10월 일산화탄소  11월 일산화탄소  12월 일산화탄소  \
# 7월 일산화탄소       1.000000  0.637344  0.575192   0.436985   0.280636   0.182790
# 8월 일산화탄소       0.637344  1.000000  0.616962   0.423246   0.297626   0.304722
# 9월 일산화탄소       0.575192  0.616962  1.000000   0.593302   0.469765   0.424256
# 10월 일산화탄소      0.436985  0.423246  0.593302   1.000000   0.721782   0.652370
# 11월 일산화탄소      0.280636  0.297626  0.469765   0.721782   1.000000   0.829055
# ...                 ...       ...       ...        ...        ...        ...
# 3월 아황산가스       0.397083  0.307230  0.322514   0.450911   0.320298   0.301431
# 4월 아황산가스       0.401351  0.363010  0.238503   0.241057   0.029555  -0.007639
# 5월 아황산가스       0.419104  0.307828  0.167740   0.144727  -0.070159  -0.150854
# 6월 아황산가스       0.422477  0.292706  0.169184   0.092478  -0.120116  -0.193289
# 10a당 생산량 (kg) -0.107971 -0.175771 -0.311435  -0.404550  -0.472730  -0.463035
#
# ...

# %%
from scipy import stats

# %%
clean = df.dropna()

# %%
x_list = ['1월 일산화탄소', '2월 일산화탄소', '3월 일산화탄소', '4월 일산화탄소',
       '5월 일산화탄소', '6월 일산화탄소', '7월 일산화탄소', '8월 일산화탄소', '9월 일산화탄소', '10월 일산화탄소',
       '11월 일산화탄소', '12월 일산화탄소', '1월 미세먼지PM10', '2월 미세먼지PM10', '3월 미세먼지PM10',
       '4월 미세먼지PM10', '5월 미세먼지PM10', '6월 미세먼지PM10', '7월 미세먼지PM10',
       '8월 미세먼지PM10', '9월 미세먼지PM10', '10월 미세먼지PM10', '11월 미세먼지PM10',
       '12월 미세먼지PM10', '1월 이산화질소', '2월 이산화질소', '3월 이산화질소', '4월 이산화질소',
       '5월 이산화질소', '6월 이산화질소', '7월 이산화질소', '8월 이산화질소', '9월 이산화질소', '10월 이산화질소',
       '11월 이산화질소', '12월 이산화질소', '1월 오존', '2월 오존', '3월 오존', '4월 오존', '5월 오존',
       '6월 오존', '7월 오존', '8월 오존', '9월 오존', '10월 오존', '11월 오존', '12월 오존',
       '1월 아황산가스', '2월 아황산가스', '3월 아황산가스', '4월 아황산가스', '5월 아황산가스', '6월 아황산가스',
       '7월 아황산가스', '8월 아황산가스', '9월 아황산가스', '10월 아황산가스', '11월 아황산가스',
       '12월 아황산가스']

# %%
p_value = []
corr = []

# %%
for item in x_list:
    corr.append(stats.pearsonr(clean[item],  clean['10a당 생산량 (kg)'])[0])
    p_value.append(stats.pearsonr(clean[item],  clean['10a당 생산량 (kg)'])[1])

# %%
x_list = pd.DataFrame(x_list).rename(columns = {0:'변수명'})
corr = pd.DataFrame(corr).rename(columns = {0:'상관계수'})
p_value = pd.DataFrame(p_value).rename(columns = {0:'p-value'})
p_list = pd.concat([x_list, corr, p_value], axis = 1)

# %%
air_val_list = p_list[p_list['p-value'] < 0.05]
air_val_list
# Out:
#              변수명      상관계수       p-value
# 0       1월 일산화탄소 -0.505235  4.120969e-10
# 1       2월 일산화탄소 -0.476904  4.989219e-09
# 2       3월 일산화탄소 -0.436909  1.171179e-07
# 3       4월 일산화탄소 -0.297658  4.546790e-04
# 7       8월 일산화탄소 -0.175771  4.143090e-02
# 8       9월 일산화탄소 -0.311435  2.362064e-04
# 9      10월 일산화탄소 -0.404550  1.136418e-06
# 10     11월 일산화탄소 -0.472730  7.070326e-09
# 11     12월 일산화탄소 -0.463035  1.560782e-08
# 12   1월 미세먼지PM10 -0.332857  7.994280e-05
# 13   2월 미세먼지PM10 -0.373214  8.265151e-06
# 14   3월 미세먼지PM10 -0.313686  2.115816e-04
# 15   4월 미세먼지PM10 -0.265716  1.840555e-03
# 16   5월 미세먼지PM10 -0.179378  3.736814e-02
# 17   6월 미세먼지PM10 -0.184939  3.176336e-02
# 20   9월 미세먼지PM10 -0.210311  1.435273e-02
# 21  10월 미세먼지PM10 -0.211050  1.400569e-02
# 23  12월 미세먼지PM10 -0.316968  1.799312e-04
# 24      1월 이산화질소 -0.408276  8.852993e-07
# 25      2월 이산화질소 -0.396896  1.880297e-06
# 26      3월 이산화질소 -0.374714  7.550806e-06
# 27      4월 이산화질소 -0.368603  1.088167e-05
# ...

# %%
air_val_list.to_csv('air_val_list.csv', encoding = 'utf-8', index = False)

# %%
air_val_list.reset_index(drop=True, inplace = True)

# %%
co = pd.read_csv('refined_co.csv', encoding = 'CP949')
dust = pd.read_csv('refined_dust.csv', encoding = 'CP949')
no2 = pd.read_csv('refined_no2.csv', encoding = 'CP949')
o3 = pd.read_csv('refined_o3.csv', encoding = 'CP949')
so2 = pd.read_csv('refined_so2.csv', encoding = 'CP949')
output = pd.read_csv('onion_unit_ouput.csv')

df = co
air_list = [co, dust, no2, o3, so2, output]

for i in range(1, 6):
    df = pd.merge(df, air_list[i], how = 'outer')

# %%
tag = df.iloc[:, :3]

# %%
for i in range(len(air_val_list)):
    name = air_val_list['변수명'][i]
    var = df[name]
    tag = pd.concat([tag, var], axis = 1)
tag
# Out:
#      year_local   area  year  1월 일산화탄소  2월 일산화탄소  3월 일산화탄소  4월 일산화탄소  \
# 0    2010_부산광역시  부산광역시  2010       0.5       0.5       0.4       0.4
# 1    2011_부산광역시  부산광역시  2011       0.4       0.5       0.4       0.4
# 2    2012_부산광역시  부산광역시  2012       0.4       0.4       0.4       0.4
# 3    2013_부산광역시  부산광역시  2013       0.5       0.5       0.5       0.4
# 4    2014_부산광역시  부산광역시  2014       0.5       0.4       0.4       0.4
# ..          ...    ...   ...       ...       ...       ...       ...
# 145    2015_제주도    제주도  2015       0.3       0.4       0.4       0.4
# 146    2016_제주도    제주도  2016       0.4       0.3       0.3       0.3
# 147    2017_제주도    제주도  2017       0.3       0.3       0.3       0.3
# 148    2018_제주도    제주도  2018       0.3       0.3       0.4       0.3
# 149    2019_제주도    제주도  2019       0.4       0.4       0.3       0.3
#
#      8월 일산화탄소  9월 일산화탄소  10월 일산화탄소  ...  9월 오존  10월 오존  11월 오존  12월 오존  \
# ...

# %%
tag.dropna(inplace = True)

# %%
selected_var_air = tag
selected_var_air.to_csv('svair.csv', index = False)
